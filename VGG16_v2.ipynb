# %% [markdown]
# # Breast Cancer Histology Image Classification Using VGG16 (Transfer Learning)
# ***
# ## Description
# This code implements a binary classification model to distinguish between benign and malignant breast cancer histology images using transfer learning with the VGG16 architecture.
#
# ## Key Steps
#
# ### 1. Data Loading & Preparation
# - Loads images from two directories:
#   - `benign_dir`: Contains benign tumor histology slides (class 0)
#   - `malignant_dir`: Contains malignant tumor histology slides (class 1)
# - Uses `train_test_split()` to create a 70-30 train-test split (stratified to maintain class balance).
#
# ### 2. Image Preprocessing
# - Images are:
#   - Resized to 224x224 (VGG16 input size)
#   - Normalized to [0, 1]
#   - Converted into a TensorFlow Dataset for efficient batching.
#
# ### 3. Model Architecture (Transfer Learning)
# - Uses VGG16 (pre-trained on ImageNet) as a feature extractor.
# - Freezes all VGG16 layers to retain pre-trained weights.
# - Adds a custom classification head:
#   - `Flatten()` → `Dense(128, ReLU)` → `Dense(1, Sigmoid)` (binary output).
#
# ### 4. Training & Evaluation
# - Compiles the model with:
#   - Optimizer: Adam
#   - Loss: Binary Crossentropy
#   - Metric: Accuracy
# - Trains for 10 epochs on the training set.
# - Evaluates on the test set and computes predictions (threshold > 0.5 for class assignment).
#
# ## Key Metrics
# - **F1-score** and **Geometric Mean Score (G-mean)** are imported (though not explicitly computed in this snippet).
# - Model performance can be further analyzed using confusion matrices, ROC curves, or precision-recall metrics.
#
# ## Usage Notes
# - Ensure the dataset path (`/content/drive/MyDrive/Datasets/...`) is correctly mounted in Google Colab.
# - Adjust `BATCH_SIZE` and `EPOCHS` based on available computational resources.
# - For imbalanced datasets, consider class weights or augmentation techniques to improve generalization.

# %% [markdown]
# ***
# **Magnification Factor: 40X**
# ***

# %%
import os
import tensorflow as tf
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from imblearn.metrics import geometric_mean_score

# Define dataset paths
benign_dir = "/content/drive/MyDrive/Datasets/BreaKHis_v1/histology_slides/benign/40X"
malignant_dir = "/content/drive/MyDrive/Datasets/BreaKHis_v1/histology_slides/malignant/40X"

# Function to load image paths
def load_image_paths(dir_path):
    return [os.path.join(dir_path, img) for img in os.listdir(dir_path) if img.endswith('.png')]

benign_images = load_image_paths(benign_dir)
malignant_images = load_image_paths(malignant_dir)

print(f"Total Benign Images: {len(benign_images)}")
print(f"Total Malignant Images: {len(malignant_images)}")

# Create labels (0 = Benign, 1 = Malignant)
benign_labels = [0] * len(benign_images)
malignant_labels = [1] * len(malignant_images)

# Combine images and labels
all_images = np.array(benign_images + malignant_images)
all_labels = np.array(benign_labels + malignant_labels)

# Split into training (70%) and testing (30%)
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.3, stratify=all_labels, random_state=42
)

print(f"Training samples: {len(train_images)}")
print(f"Testing samples: {len(test_images)}")

# Function to preprocess images
def process_path(file_path, label):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=3)  # Decode PNG images
    img = tf.image.resize(img, [224, 224])  # Resize to 224x224
    img = img / 255.0  # Normalize pixel values
    return img, label

# Create TensorFlow datasets
BATCH_SIZE = 128

train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_dataset = train_dataset.map(process_path).shuffle(1000).batch(BATCH_SIZE)

test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_dataset = test_dataset.map(process_path).batch(BATCH_SIZE)

# Ensure testing dataset is not empty
if sum(1 for _ in test_dataset) == 0:
    raise ValueError("Testing dataset is empty. Adjust your dataset split.")

# Load VGG16 without the top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom classifier on top
x = Flatten()(base_model.output)
x = Dense(128, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)  # Binary classification

# Create the model
model = Model(inputs=base_model.input, outputs=x)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
EPOCHS = 100
history = model.fit(train_dataset, epochs=EPOCHS)

# Evaluate model
test_preds = model.predict(test_dataset)
test_preds = (test_preds > 0.5).astype(int).flatten()
from sklearn.metrics import confusion_matrix

# Evaluate model
test_preds = model.predict(test_dataset)
test_preds = (test_preds > 0.5).astype(int).flatten()

# Get confusion matrix values
tn, fp, fn, tp = confusion_matrix(test_labels, test_preds).ravel()

# Calculate IBA
iba = (tp / (tp + fn)) + (tn / (tn + fp)) - 1

# Output results
f1 = f1_score(test_labels, test_preds)
gmean = geometric_mean_score(test_labels, test_preds)

loss, accuracy = model.evaluate(test_dataset)
print(f"Test Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f
dir = "/content/drive/MyDrive/Datasets/BreaKHis_v1/histology_slides/malignant/100X"

# Function to load image paths
def load_image_paths(dir_path):
    return [os.path.join(dir_path, img) for img in os.listdir(dir_path) if img.endswith('.png')]

benign_images = load_image_paths(benign_dir)
malignant_images = load_image_paths(malignant_dir)

print(f"Total Benign Images: {len(benign_images)}")
print(f"Total Malignant Images: {len(malignant_images)}")

# Create labels (0 = Benign, 1 = Malignant)
benign_labels = [0] * len(benign_images)
malignant_labels = [1] * len(malignant_images)

# Combine images and labels
all_images = np.array(benign_images + malignant_images)
all_labels = np.array(benign_labels + malignant_labels)

# Split into training (70%) and testing (30%)
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.3, stratify=all_labels, random_state=42
)

print(f"Training samples: {len(train_images)}")
print(f"Testing samples: {len(test_images)}")

# Function to preprocess images
def process_path(file_path, label):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=3)  # Decode PNG images
    img = tf.image.resize(img, [224, 224])  # Resize to 224x224
    img = img / 255.0  # Normalize pixel values
    return img, label

# Create TensorFlow datasets
BATCH_SIZE = 128

train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_dataset = train_dataset.map(process_path).shuffle(1000).batch(BATCH_SIZE)

test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_dataset = test_dataset.map(process_path).batch(BATCH_SIZE)

# Ensure testing dataset is not empty
if sum(1 for _ in test_dataset) == 0:
    raise ValueError("Testing dataset is empty. Adjust your dataset split.")

# Load VGG16 without the top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom classifier on top
x = Flatten()(base_model.output)
x = Dense(128, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)  # Binary classification

# Create the model
model = Model(inputs=base_model.input, outputs=x)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
EPOCHS = 100
history = model.fit(train_dataset, epochs=EPOCHS)

# Evaluate model
test_preds = model.predict(test_dataset)
test_preds = (test_preds > 0.5).astype(int).flatten()
from sklearn.metrics import confusion_matrix

# Evaluate model
test_preds = model.predict(test_dataset)
test_preds = (test_preds > 0.5).astype(int).flatten()

# Get confusion matrix values
tn, fp, fn, tp = confusion_matrix(test_labels, test_preds).ravel()

# Calculate IBA
iba = (tp / (tp + fn)) + (tn / (tn + fp)) - 1

# Output results
f1 = f1_score(test_labels, test_preds)
gmean = geometric_mean_score(test_labels, test_preds)

loss, accuracy = model.evaluate(test_dataset)
print(f"Test Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"G-Mean: {gmean:.4f}")
print(f"Informedness (IBA): {iba:.4f}")
# Out:
# Total Benign Images: 649
# Total Malignant Images: 1437
# Training samples: 1460
# Testing samples: 626
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - accuracy: 0.5796 - loss: 1.8177
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 684ms/step - accuracy: 0.7782 - loss: 0.5041
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 668ms/step - accuracy: 0.8110 - loss: 0.3950
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 695ms/step - accuracy: 0.8732 - loss: 0.2958
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 662ms/step - accuracy: 0.9055 - loss: 0.2407
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 695ms/step - accuracy: 0.9392 - loss: 0.2094
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 648ms/step - accuracy: 0.9401 - loss: 0.1883
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 668ms/step - accuracy: 0.9573 - loss: 0.1627
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 823ms/step - accuracy: 0.9716 - loss: 0.1345
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 658ms/step - accuracy: 0.9776 - loss: 0.1119
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 703ms/step - accuracy: 0.9814 - loss: 0.1074
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 659ms/step - accuracy: 0.9910 - loss: 0.0852
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 756ms/step - accuracy: 0.9928 - loss: 0.0759
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 648ms/step - accuracy: 0.9908 - loss: 0.0734
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 793ms/step - accuracy: 0.9951 - loss: 0.0661
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 642ms/step - accuracy: 0.9965 - loss: 0.0574
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 792ms/step - accuracy: 0.9972 - loss: 0.0553
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 644ms/step - accuracy: 0.9975 - loss: 0.0456
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 793ms/step - accuracy: 0.9977 - loss: 0.0432
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 639ms/step - accuracy: 0.9952 - loss: 0.0409
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 22s 728ms/step - accuracy: 0.9989 - loss: 0.0331
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 645ms/step - accuracy: 0.9990 - loss: 0.0304
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 797ms/step - accuracy: 0.9993 - loss: 0.0281
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 648ms/step - accuracy: 0.9996 - loss: 0.0229
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 791ms/step - accuracy: 0.9981 - loss: 0.0249
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 655ms/step - accuracy: 0.9996 - loss: 0.0207
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 762ms/step - accuracy: 0.9996 - loss: 0.0179
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 658ms/step - accuracy: 0.9981 - loss: 0.0190
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 752ms/step - accuracy: 0.9996 - loss: 0.0159
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 646ms/step - accuracy: 1.0000 - loss: 0.0150
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 734ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 665ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 751ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 645ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 751ms/step - accuracy: 1.0000 - loss: 0.0093
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 651ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 731ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 650ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 787ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 672ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 771ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 41s 666ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 23s 804ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 687ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 774ms/step - accuracy: 1.0000 - loss: 0.0051
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 675ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 735ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 661ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 724ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 649ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 646ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 677ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 645ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 646ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 655ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 653ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 645ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 645ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 677ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 649ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 646ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 650ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 667ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 655ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 650ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 22s 764ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 768ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 639ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 759ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 645ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 662ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 650ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 699ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 649ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 793ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 649ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 788ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 653ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 735ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 650ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 684ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 659ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 646ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 723ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 639ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 735ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 641ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 771ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 780ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 644ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 646ms/step - accuracy: 1.0000 - loss: 9.1572e-04
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 642ms/step - accuracy: 1.0000 - loss: 9.3247e-04
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 721ms/step - accuracy: 1.0000 - loss: 9.7378e-04
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 649ms/step - accuracy: 1.0000 - loss: 8.7952e-04
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 710ms/step - accuracy: 1.0000 - loss: 8.9291e-04
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 648ms/step - accuracy: 1.0000 - loss: 8.7682e-04
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 643ms/step - accuracy: 1.0000 - loss: 8.3705e-04
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 645ms/step - accuracy: 1.0000 - loss: 8.3066e-04
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 642ms/step - accuracy: 1.0000 - loss: 8.0124e-04
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 647ms/step - accuracy: 1.0000 - loss: 7.9566e-04
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 36s 8s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8846 - loss: 0.4164
# Test Accuracy: 0.8754
# F1 Score: 0.9122
# G-Mean: 0.8301
# Informedness (IBA): 0.6730

# %% [markdown]
# ***
# **Magnification Factor: 200X**
# ***

# %%
import os
import tensorflow as tf
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from imblearn.metrics import geometric_mean_score

# Define dataset paths
benign_dir = "/content/drive/MyDrive/Datasets/BreaKHis_v1/histology_slides/benign/200X"
malignant_dir = "/content/drive/MyDrive/Datasets/BreaKHis_v1/histology_slides/malignant/200X"

# Function to load image paths
def load_image_paths(dir_path):
    return [os.path.join(dir_path, img) for img in os.listdir(dir_path) if img.endswith('.png')]

benign_images = load_image_paths(benign_dir)
malignant_images = load_image_paths(malignant_dir)

print(f"Total Benign Images: {len(benign_images)}")
print(f"Total Malignant Images: {len(malignant_images)}")

# Create labels (0 = Benign, 1 = Malignant)
benign_labels = [0] * len(benign_images)
malignant_labels = [1] * len(malignant_images)

# Combine images and labels
all_images = np.array(benign_images + malignant_images)
all_labels = np.array(benign_labels + malignant_labels)

# Split into training (70%) and testing (30%)
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.3, stratify=all_labels, random_state=42
)

print(f"Training samples: {len(train_images)}")
print(f"Testing samples: {len(test_images)}")

# Function to preprocess images
def process_path(file_path, label):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=3)  # Decode PNG images
    img = tf.image.resize(img, [224, 224])  # Resize to 224x224
    img = img / 255.0  # Normalize pixel values
    return img, label

# Create TensorFlow datasets
BATCH_SIZE = 128

train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_dataset = train_dataset.map(process_path).shuffle(1000).batch(BATCH_SIZE)

test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_dataset = test_dataset.map(process_path).batch(BATCH_SIZE)

# Ensure testing dataset is not empty
if sum(1 for _ in test_dataset) == 0:
    raise ValueError("Testing dataset is empty. Adjust your dataset split.")

# Load VGG16 without the top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom classifier on top
x = Flatten()(base_model.output)
x = Dense(128, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)  # Binary classification

# Create the model
model = Model(inputs=base_model.input, outputs=x)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
EPOCHS = 100
history = model.fit(train_dataset, epochs=EPOCHS)

# Evaluate model
test_preds = model.predict(test_dataset)
test_preds = (test_preds > 0.5).astype(int).flatten()
from sklearn.metrics import confusion_matrix

# Evaluate model
test_preds = model.predict(test_dataset)
test_preds = (test_preds > 0.5).astype(int).flatten()

# Get confusion matrix values
tn, fp, fn, tp = confusion_matrix(test_labels, test_preds).ravel()

# Calculate IBA
iba = (tp / (tp + fn)) + (tn / (tn + fp)) - 1

# Output results
f1 = f1_score(test_labels, test_preds)
gmean = geometric_mean_score(test_labels, test_preds)

loss, accuracy = model.evaluate(test_dataset)
print(f"Test Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"G-Mean: {gmean:.4f}")
print(f"Informedness (IBA): {iba:.4f}")
# Out:
# Total Benign Images: 623
# Total Malignant Images: 1390
# Training samples: 1409
# Testing samples: 604
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 596ms/step - accuracy: 0.9997 - loss: 0.0256
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 710ms/step - accuracy: 1.0000 - loss: 0.0241
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 725ms/step - accuracy: 1.0000 - loss: 0.0244
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 683ms/step - accuracy: 1.0000 - loss: 0.0223
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 600ms/step - accuracy: 1.0000 - loss: 0.0208
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 720ms/step - accuracy: 1.0000 - loss: 0.0206
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 596ms/step - accuracy: 1.0000 - loss: 0.0180
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 640ms/step - accuracy: 1.0000 - loss: 0.0169
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 598ms/step - accuracy: 1.0000 - loss: 0.0246
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 597ms/step - accuracy: 1.0000 - loss: 0.0199
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 619ms/step - accuracy: 1.0000 - loss: 0.0155
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 599ms/step - accuracy: 0.9992 - loss: 0.0186
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 594ms/step - accuracy: 1.0000 - loss: 0.0187
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 596ms/step - accuracy: 1.0000 - loss: 0.0147
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 655ms/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 22s 601ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 621ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 593ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 22s 722ms/step - accuracy: 0.9915 - loss: 0.0456
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 596ms/step - accuracy: 1.0000 - loss: 0.0185
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 678ms/step - accuracy: 0.9981 - loss: 0.0189
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 599ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 614ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 594ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 593ms/step - accuracy: 1.0000 - loss: 0.0188
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 643ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 594ms/step - accuracy: 1.0000 - loss: 0.0089
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 731ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 592ms/step - accuracy: 1.0000 - loss: 0.0174
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 652ms/step - accuracy: 1.0000 - loss: 0.0109
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 600ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 601ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 596ms/step - accuracy: 1.0000 - loss: 0.0074
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 592ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 663ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 588ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 634ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 588ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 710ms/step - accuracy: 1.0000 - loss: 0.0055
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 590ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 685ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 599ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 642ms/step - accuracy: 1.0000 - loss: 0.0052
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 32s 7s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8631 - loss: 0.3986
# Test Accuracy: 0.8692
# F1 Score: 0.9082
# G-Mean: 0.8197
# Informedness (IBA): 0.6542

# %% [markdown]
# ***
# **Magnification Factor: 400X**
# ***

# %%
import os
import tensorflow as tf
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from imblearn.metrics import geometric_mean_score

# Define dataset paths
benign_dir = "/content/drive/MyDrive/Datasets/BreaKHis_v1/histology_slides/benign/400X"
malignant_dir = "/content/drive/MyDrive/Datasets/BreaKHis_v1/histology_slides/malignant/400X"

# Function to load image paths
def load_image_paths(dir_path):
    return [os.path.join(dir_path, img) for img in os.listdir(dir_path) if img.endswith('.png')]

benign_images = load_image_paths(benign_dir)
malignant_images = load_image_paths(malignant_dir)

print(f"Total Benign Images: {len(benign_images)}")
print(f"Total Malignant Images: {len(malignant_images)}")

# Create labels (0 = Benign, 1 = Malignant)
benign_labels = [0] * len(benign_images)
malignant_labels = [1] * len(malignant_images)

# Combine images and labels
all_images = np.array(benign_images + malignant_images)
all_labels = np.array(benign_labels + malignant_labels)

# Split into training (70%) and testing (30%)
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.3, stratify=all_labels, random_state=42
)

print(f"Training samples: {len(train_images)}")
print(f"Testing samples: {len(test_images)}")

# Function to preprocess images
def process_path(file_path, label):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_png(img, channels=3)  # Decode PNG images
    img = tf.image.resize(img, [224, 224])  # Resize to 224x224
    img = img / 255.0  # Normalize pixel values
    return img, label

# Create TensorFlow datasets
BATCH_SIZE = 128

train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_dataset = train_dataset.map(process_path).shuffle(1000).batch(BATCH_SIZE)

test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_dataset = test_dataset.map(process_path).batch(BATCH_SIZE)

# Ensure testing dataset is not empty
if sum(1 for _ in test_dataset) == 0:
    raise ValueError("Testing dataset is empty. Adjust your dataset split.")

# Load VGG16 without the top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom classifier on top
x = Flatten()(base_model.output)
x = Dense(128, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)  # Binary classification

# Create the model
model = Model(inputs=base_model.input, outputs=x)

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
EPOCHS = 100
history = model.fit(train_dataset, epochs=EPOCHS)

# Evaluate model
test_preds = model.predict(test_dataset)
test_preds = (test_preds > 0.5).astype(int).flatten()
from sklearn.metrics import confusion_matrix

# Evaluate model
test_preds = model.predict(test_dataset)
test_preds = (test_preds > 0.5).astype(int).flatten()

# Get confusion matrix values
tn, fp, fn, tp = confusion_matrix(test_labels, test_preds).ravel()

# Calculate IBA
iba = (tp / (tp + fn)) + (tn / (tn + fp)) - 1

# Output results
f1 = f1_score(test_labels, test_preds)
gmean = geometric_mean_score(test_labels, test_preds)

loss, accuracy = model.evaluate(test_dataset)
print(f"Test Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f
    'F1 Score': [0.8952, 0.9122, 0.9082, 0.8906],
    'G-Mean': [0.8105, 0.8301, 0.8197, 0.7939],
    'Informedness (IBA)': [0.6329, 0.6730, 0.6542, 0.6061]
}

df = pd.DataFrame(data)

# Display the table with formatting
styled_df = df.style \
    .format({
        'Test Accuracy': '{:.4f}',
        'F1 Score': '{:.4f}',
        'G-Mean': '{:.4f}',
        'Informedness (IBA)': '{:.4f}'
    }) \
    .set_properties(**{'text-align': 'center'}) \
    .set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#000000'), ('font-weight', 'bold'), ('color', 'white')]}
    ]) \
    .hide(axis='index')

styled_df
# Out:
# <style type="text/css">
# #T_cbc85 th {
#   background-color: #000000;
#   font-weight: bold;
#   color: white;
# }
# #T_cbc85_row0_col0, #T_cbc85_row0_col1, #T_cbc85_row0_col2, #T_cbc85_row0_col3, #T_cbc85_row0_col4, #T_cbc85_row1_col0, #T_cbc85_row1_col1, #T_cbc85_row1_col2, #T_cbc85_row1_col3, #T_cbc85_row1_col4, #T_cbc85_row2_col0, #T_cbc85_row2_col1, #T_cbc85_row2_col2, #T_cbc85_row2_col3, #T_cbc85_row2_col4, #T_cbc85_row3_col0, #T_cbc85_row3_col1, #T_cbc85_row3_col2, #T_cbc85_row3_col3, #T_cbc85_row3_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_cbc85" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_cbc85_level0_col0" class="col_heading level0 col0" >Magnification</th>
#       <th id="T_cbc85_level0_col1" class="col_heading level0 col1" >Test Accuracy</th>
#       <th id="T_cbc85_level0_col2" class="col_heading level0 col2" >F1 Score</th>
#       <th id="T_cbc85_level0_col3" class="col_heading level0 col3" >G-Mean</th>
#       <th id="T_cbc85_level0_col4" class="col_heading level0 col4" >Informedness (IBA)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cbc85_row0_col0" class="data row0 col0" >40X</td>
#       <td id="T_cbc85_row0_col1" class="data row0 col1" >0.8531</td>
#       <td id="T_cbc85_row0_col2" class="data row0 col2" >0.8952</td>
#       <td id="T_cbc85_row0_col3" class="data row0 col3" >0.8105</td>
#       <td id="T_cbc85_row0_col4" class="data row0 col4" >0.6329</td>
#     </tr>
#     <tr>
#       <td id="T_cbc85_row1_col0" class="data row1 col0" >100X</td>
#       <td id="T_cbc85_row1_col1" class="data row1 col1" >0.8754</td>
#       <td id="T_cbc85_row1_col2" class="data row1 col2" >0.9122</td>
#       <td id="T_cbc85_row1_col3" class="data row1 col3" >0.8301</td>
#       <td id="T_cbc85_row1_col4" class="data row1 col4" >0.6730</td>
#     </tr>
#     <tr>
#       <td id="T_cbc85_row2_col0" class="data row2 col0" >200X</td>
#       <td id="T_cbc85_row2_col1" class="data row2 col1" >0.8692</td>
#       <td id="T_cbc85_row2_col2" class="data row2 col2" >0.9082</td>
#       <td id="T_cbc85_row2_col3" class="data row2 col3" >0.8197</td>
#       <td id="T_cbc85_row2_col4" class="data row2 col4" >0.6542</td>
#     </tr>
#     <tr>
#       <td id="T_cbc85_row3_col0" class="data row3 col0" >400X</td>
#       <td id="T_cbc85_row3_col1" class="data row3 col1" >0.8462</td>
#       <td id="T_cbc85_row3_col2" class="data row3 col2" >0.8906</td>
#       <td id="T_cbc85_row3_col3" class="data row3 col3" >0.7939</td>
#       <td id="T_cbc85_row3_col4" class="data row3 col4" >0.6061</td>
#     </tr>
#   </tbody>
# </table>
